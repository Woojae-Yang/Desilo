# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
basic1 = pd.read_csv('C:/Users/WoojaeYang/Desktop/DCR/data/basic1.csv')
basic1.head()
# Out:
#      id   age city    f1  f2   f3    f4         f5
# 0  id01   2.0   서울   NaN   0  NaN  ENFJ  91.297791
# 1  id02   9.0   서울  70.0   1  NaN  ENFJ  60.339826
# 2  id03  27.0   서울  61.0   1  NaN  ISTJ  17.252986
# 3  id04  75.0   서울   NaN   2  NaN  INFP  52.667078
# 4  id05  24.0   서울  85.0   2  NaN  ISFJ  29.269869

# %%
plt.figure(figsize=(8, 6))
counts, bin_edges, _ = plt.hist(basic1['age'], color='orange', edgecolor='black', alpha=0.7, bins=20)
plt.show()

# %%
print("각 구간(bin)의 도수:", counts)
print("구간(bin) 경계값:", bin_edges)
# Out:
# 각 구간(bin)의 도수: [2. 1. 6. 3. 1. 5. 6. 4. 9. 6. 5. 5. 5. 4. 6. 9. 2. 9. 6. 6.]
# 구간(bin) 경계값: [-13.5    -7.825  -2.15    3.525   9.2    14.875  20.55   26.225  31.9
#   37.575  43.25   48.925  54.6    60.275  65.95   71.625  77.3    82.975
#   88.65   94.325 100.   ]

# %%
basic1.describe()
# Out:
#               age          f1          f2          f5
# count  100.000000   69.000000  100.000000  100.000000
# mean    50.963000   66.043478    0.650000   56.734537
# std     30.442759   19.453893    0.715979   28.454244
# min    -13.500000   12.000000    0.000000    9.796378
# 25%     26.875000   51.000000    0.000000   29.269869
# 50%     52.500000   63.000000    1.000000   64.113099
# 75%     77.000000   78.000000    1.000000   81.025055
# max    100.000000  111.000000    2.000000   98.429899

# %%
plt.hist(basic1['f1'], color='orange', edgecolor='black', alpha=0.7, bins=20)
plt.show()

# %%
basic1.nunique()
# Out:
# id      100
# age      71
# city      4
# f1       43
# f2        3
# f3        1
# f4       16
# f5       20
# dtype: int64

# %%
plt.hist(basic1['f5'], color='orange', edgecolor='black', alpha=0.7, bins=20)
plt.show()

# %%
basic1['f4'].value_counts()
# Out:
# f4
# ESTP    11
# ISFJ    10
# ISFP    10
# ESTJ     9
# INTP     8
# ENFJ     6
# INFP     6
# ENFP     6
# ENTP     6
# ESFJ     5
# ENTJ     5
# INFJ     4
# ESFP     4
# ISTP     4
# INTJ     4
# ISTJ     2
# Name: count, dtype: int64

# %%
basic1['id'].head(20)
# Out:
# 0     id01
# 1     id02
# 2     id03
# 3     id04
# 4     id05
# 5     id06
# 6     id07
# 7     id08
# 8     id09
# 9     id10
# 10    id11
# 11    id12
# 12    id13
# 13    id14
# 14    id15
# 15    id16
# 16    id17
# 17    id18
# 18    id19
# 19    id20
# Name: id, dtype: object

# %%
titanic = pd.read_csv('C:/Users/WoojaeYang/Desktop/DCR/data/titanic.csv')
titanic['Parch'].describe()
# Out:
# count    891.000000
# mean       0.381594
# std        0.806057
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        6.000000
# Name: Parch, dtype: float64

# %%
tita_counts, tita_bin_edges, tita__ = plt.hist(titanic['Parch'], bins=20, color = 'blue', alpha = 0.5)
plt.show()

df_tita_bins = pd.DataFrame({
    'Bin_Start': tita_bin_edges[:-1],  # 구간 시작값 (마지막 값 제외)
    'Bin_End': tita_bin_edges[1:],     # 구간 끝값 (첫 번째 값 제외)
    'Count': tita_counts               # 각 구간의 도수
})
df_tita_bins
# Out:
#     Bin_Start  Bin_End  Count
# 0         0.0      0.3  678.0
# 1         0.3      0.6    0.0
# 2         0.6      0.9    0.0
# 3         0.9      1.2  118.0
# 4         1.2      1.5    0.0
# 5         1.5      1.8    0.0
# 6         1.8      2.1   80.0
# 7         2.1      2.4    0.0
# 8         2.4      2.7    0.0
# 9         2.7      3.0    0.0
# 10        3.0      3.3    5.0
# 11        3.3      3.6    0.0
# 12        3.6      3.9    0.0
# 13        3.9      4.2    4.0
# 14        4.2      4.5    0.0
# 15        4.5      4.8    0.0
# 16        4.8      5.1    5.0
# 17        5.1      5.4    0.0
# 18        5.4      5.7    0.0
# 19        5.7      6.0    1.0

# %%
payment_dt = pd.read_csv('C:/Users/WoojaeYang/Desktop/DCR/data/payment_datetime.csv')
payment_dt.nunique()
# Out:
# date               6
# hour               9
# menu              11
# price              4
# year               1
# month              2
# day                6
# formatted_date     6
# dtype: int64

# %%
payment_dt['hour']
# Out:
# 0     13
# 1     12
# 2     14
# 3     16
# 4     17
# 5     12
# 6      8
# 7      9
# 8     15
# 9     16
# 10    10
# 11    14
# 12    16
# Name: hour, dtype: int64

# %%
payment_dt
# Out:
#         date  hour    menu  price  year  month  day formatted_date
# 0   20221129    13    딸기라떼   4000  2022     11   29     2022-11-29
# 1   20221130    12    카페라떼   3000  2022     11   30     2022-11-30
# 2   20221201    14   바닐라라떼   3500  2022     12    1     2022-12-01
# 3   20221201    16    초코라떼   3500  2022     12    1     2022-12-01
# 4   20221202    17    모카라떼   3500  2022     12    2     2022-12-02
# 5   20221202    12   카라멜라떼   3500  2022     12    2     2022-12-02
# 6   20221203     8   챠이 라떼   3500  2022     12    3     2022-12-03
# 7   20221203     9   아메리카노   2000  2022     12    3     2022-12-03
# 8   20221203    15   오곡 라떼   4000  2022     12    3     2022-12-03
# 9   20221203    16   아메리카노   2000  2022     12    3     2022-12-03
# 10  20221225    10   아메리카노   2000  2022     12   25     2022-12-25
# 11  20221225    14  토피넛 라떼   4000  2022     12   25     2022-12-25
# 12  20221225    16   카페 라떼   3000  2022     12   25     2022-12-25

# %%
titanic['Ticket'].value_counts().head(5)
# Out:
# Ticket
# 347082      7
# CA. 2343    7
# 1601        7
# 3101295     6
# CA 2144     6
# Name: count, dtype: int64

# %%
blood = pd.read_csv('C:/Users/WoojaeYang/Desktop/DCR/data/high_blood_pressure.csv')
blood.head()
# Out:
#      Id     sex  age  bp_pre  bp_post
# 0  p001    Male   33     149      129
# 1  p002    Male   39     168      168
# 2  p003    Male   70     176      155
# 3  p004  Female   41     169      178
# 4  p005    Male   48     160      126

# %%
blood.describe()
# Out:
#               age      bp_pre     bp_post
# count  120.000000  120.000000  120.000000
# mean    54.508333  163.650000  157.533333
# std     13.037758   13.649053   18.357758
# min     30.000000  138.000000  125.000000
# 25%     43.000000  154.000000  140.500000
# 50%     55.000000  165.000000  161.500000
# 75%     66.000000  176.000000  174.000000
# max     79.000000  185.000000  185.000000

# %%
blood['sex'].value_counts()
# Out:
# sex
# Male      60
# Female    60
# Name: count, dtype: int64

# %%
plt.hist(blood['bp_post'], color = 'blue', bins = 20, alpha = 0.5, edgecolor='black')
plt.show()

# %%
plt.hist(blood['bp_pre'], color = 'blue', bins = 20, alpha = 0.5, edgecolor='black')
plt.show()

# %%
basic1['f3'].isnull().sum()
# Out:
# 95

# %%
blood['bp_pre'].nunique()
# Out:
# 44
